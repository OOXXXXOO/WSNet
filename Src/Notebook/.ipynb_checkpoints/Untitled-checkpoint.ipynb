# %% [markdown]
# # Notebook For Segmentation Research

# %%
import numpy as np
InputDataset="/workspace/SampledDatasetMini.npy"
NPY_Data=np.load(InputDataset,allow_pickle=True)
print(NPY_Data.shape)
# Out:
# (128,)

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(2, 2)
ax[0,0].imshow(NPY_Data[6]['data'])
ax[0,1].imshow(NPY_Data[6]['label'])

ax[1,0].imshow(NPY_Data[7]['data'])
ax[1,1].imshow(NPY_Data[7]['label'])
plt.savefig("label2.png",dpi=300)
plt.show()

# %%
import torchvision.models as models
import torch
torch.cuda.empty_cache()
input=torch.randn((2,2,768,768))
# # inputs=[input]
# # print(input)
# model=models.segmentation.deeplabv3_resnet101(pretrained=False,num_classes=2)
# # model.train()
# # model.cuda()
# # input=input.to("cuda:0")
# output=model(input)
# print(output.size())
input=torch.max(input[:],1)[1].unsqueeze(1)
print(input.size())
print(input.numpy()[0].shape)
plt.imshow(input.numpy()[0]),plt.show()
# Out:
# torch.Size([2, 1, 768, 768])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ac68d38a6642> in <module>
#      14 print(input.size())
#      15 input.numpy()[0]
# ---> 16 plt.imshow(input.numpy()[0]),plt.show()
#
# ~/anaconda3/envs/stable/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# ~/anaconda3/envs/stable/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/envs/stable/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5485                               resample=resample, **kwargs)
#    5486
# -> 5487         im.set_data(X)
#    5488         im.set_alpha(alpha)
#    5489         if im.get_clip_path() is None:
#
# ~/anaconda3/envs/stable/lib/python3.6/site-packages/matplotlib/image.py in set_data(self, A)
#     651         if not (self._A.ndim == 2
#     652                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 653             raise TypeError("Invalid dimensions for image data")
#     654
#     655         if self._A.ndim == 3:
#
# TypeError: Invalid dimensions for image data

# %%
import time
str(time.asctime(time.localtime(time.time())))
# Out:
# 'Wed Mar  4 18:38:30 2020'
