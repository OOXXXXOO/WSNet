# %%
import os
import sys
sys.path.append(sys.path[0]+"/Src")
print(sys.path)
from model import MODEL
model=MODEL(cfg="Config/instanceseg on studio.json")
# Out:
# ['/workspace/WSNet', '/opt/conda/envs/workspace/lib/python37.zip', '/opt/conda/envs/workspace/lib/python3.7', '/opt/conda/envs/workspace/lib/python3.7/lib-dynload', '', '/root/.local/lib/python3.7/site-packages', '/opt/conda/envs/workspace/lib/python3.7/site-packages', '/opt/conda/envs/workspace/lib/python3.7/site-packages/esdk_obs_python-3.20.1-py3.7.egg', '/opt/conda/envs/workspace/lib/python3.7/site-packages/IPython/extensions', '/root/.ipython', '/workspace/WSNet/Src']
# -----root : /workspace/WSNet
# -----root : /opt/conda/envs/workspace/lib/python37.zip
# -----root : /opt/conda/envs/workspace/lib/python3.7
# -----root : /opt/conda/envs/workspace/lib/python3.7/lib-dynload
# -----root :
# -----root : /root/.local/lib/python3.7/site-packages
# -----root : /opt/conda/envs/workspace/lib/python3.7/site-packages
# -----root : /opt/conda/envs/workspace/lib/python3.7/site-packages/esdk_obs_python-3.20.1-py3.7.egg
# ...

# %%
model.trainset[0]
# Out:
# (tensor([[[ 0.1254,  0.1768,  0.1768,  ..., -2.1179, -2.1008, -2.0837],
#           [ 0.1254,  0.1939,  0.2282,  ..., -2.1008, -2.0665, -2.0323],
#           [ 0.1426,  0.2111,  0.2453,  ..., -2.1179, -2.1179, -2.1008],
#           ...,
#           [-1.9467, -2.0494, -2.1179,  ..., -1.9980, -2.0152, -2.0665],
#           [-2.0665, -2.0152, -1.8953,  ..., -1.9980, -2.0323, -2.0323],
#           [-2.0837, -2.0837, -2.1008,  ..., -1.9980, -2.0323, -2.0494]],
#
#          [[ 0.9055,  0.9580,  0.9580,  ..., -1.6506, -1.6331, -1.6155],
#           [ 0.9055,  0.9755,  1.0105,  ..., -1.6506, -1.6331, -1.5980],
#           [ 0.9230,  0.9930,  1.0280,  ..., -1.7031, -1.6856, -1.6681],
#           ...,
#           [-1.9657, -1.8606, -1.8431,  ..., -2.0182, -2.0182, -2.0182],
#           [-2.0007, -2.0007, -1.8957,  ..., -1.9832, -2.0357, -2.0357],
#           [-1.9482, -1.9832, -1.9832,  ..., -1.9832, -2.0357, -2.0357]],
#
# ...
